# %%
import importlib

importlib.import_module('utils')

import utils

import traceback

try:
    application_path = "data2/DENVER-25CAP-00000-04SUF-ID.json"

    license_path = "extracted.json"
    
    license = utils.load_file_as_json(license_path)
    
    application = utils.load_file_as_json(application_path)
    
except Exception as e:
    print(f"Error while validating {load_file_as_json}: {e}")

    traceback.print_exc()
